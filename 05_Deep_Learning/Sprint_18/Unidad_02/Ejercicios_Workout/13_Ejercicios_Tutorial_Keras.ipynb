# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre **Keras y DL**, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %% [markdown]
# ### Predecir eficiencia de gasolina

# %% [markdown]
# En este conjuntos de ejercicios vamos a trabajar sobre el set de datos clasico [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) para construir un modelo DL para predecir el consumo de vehiculos de 1970 y 1980. Para hacer esto proveeremos el modelo con una descripcion de muchos automoviles de ese periodo. Esta descripcion incluye atributos como: Cilindros, desplazamiento, potencia y peso.
#
# El objetivo de este ejercicio es predecir el target miles per galon (MPG), que vendría a representar las millas por galón de combustible.
#
# Para la construcción del modelo vamos a utilizar Keras.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ### Ejercicio 1
#
# Carga los datos en un dataframe, utilizando como nombre de columnas los siguientes:
#
# ```python
# column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight', 'Acceleration', 'Model Year', 'Origin']
# ```

# %% [markdown]
# Hay que tratarlo, ya que es un archivo .txt, para obtener el DataFrame

# %%
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight', 'Acceleration', 'Model Year', 'Origin']

with open("./data/Autos_data.txt") as f:
    datos = f.read()

lista_datos = []

for linea in datos.split("\n"):
    datos = {clave.lower():dato for clave,dato in zip(column_names,linea.split())}
    lista_datos.append(datos)

df = pd.DataFrame(lista_datos)
df.head()
# Out:
#     mpg cylinders displacement horsepower weight acceleration model year  \
# 0  18.0         8        307.0      130.0  3504.         12.0         70
# 1  15.0         8        350.0      165.0  3693.         11.5         70
# 2  18.0         8        318.0      150.0  3436.         11.0         70
# 3  16.0         8        304.0      150.0  3433.         12.0         70
# 4  17.0         8        302.0      140.0  3449.         10.5         70
#
#   origin
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    object
#  1   cylinders     398 non-null    object
#  2   displacement  398 non-null    object
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    object
#  5   acceleration  398 non-null    object
#  6   model year    398 non-null    object
#  7   origin        398 non-null    object
# dtypes: object(8)
# memory usage: 25.0+ KB

# %% [markdown]
# ### Ejercicio 2: Limpieza inicial
#
# Echa un primer vistazo. Limpia columnas "raras". Deshazte de nulos (cuidado aquí), arregla el tipo de las features numéricas si fuera necesario. Haz una lista de las features categóricas que tuvieramos que convertir posteriormente. (Es antes del split pero no importa para este ejercicio)

# %% [markdown]
# Limpiamos la columna `weight`

# %%
df["weight"] = df["weight"].str.replace(".","").astype(int)

# %% [markdown]
# No hay columnas categóricas cuyos valores tengamos que convertir a numéricas, aunque el tipo de las columnas es "object". Las convertimos a tipo numérico

# %%
df = df.astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 df = df.astype("float")
#
# File c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '?'

# %% [markdown]
# Da un error porque ha encontrado el caracter "?" en alguna columna, que parece indicar *missing*. Lo convertimos a nulo

# %%
for col in df.columns:
    df[col] = df[col].apply(lambda row: row if str(row) != "?" else np.nan).astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    float64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    float64
#  7   origin        398 non-null    float64
# dtypes: float64(8)
# memory usage: 25.0 KB

# %% [markdown]
# Hay 6 nulos en `horsepower`. Los eliminamos

# %%
df.dropna(inplace = True)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0        4.0         140.0        86.0  2790.0          15.6
# 394  44.0        4.0          97.0        52.0  2130.0          24.6
# 395  32.0        4.0         135.0        84.0  2295.0          11.6
# 396  28.0        4.0         120.0        79.0  2625.0          18.6
# 397  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      model year  origin
# 0          70.0     1.0
# 1          70.0     1.0
# 2          70.0     1.0
# 3          70.0     1.0
# 4          70.0     1.0
# ..          ...     ...
# 393        82.0     1.0
# 394        82.0     2.0
# 395        82.0     1.0
# 396        82.0     1.0
# 397        82.0     1.0
#
# [392 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    float64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    float64
#  7   origin        392 non-null    float64
# dtypes: float64(8)
# memory usage: 27.6 KB

# %% [markdown]
# ### Ejercicio 3
#
# Antes de seguir nos informan que las etiquetas de "origin" correspoden a  USA para el 1, Europa para el 2 y Japón para el 3. Convierte origin a esos valores porque queremos tener el literal. Luego haz directamente un one-hot encoding de esas variable.
#
# *NOTA: Realmente los one-hot-encoding se pueden hacer contra el dataset original desde el principio (no afectan unos a otros), si nos los hacemos es porque hasta que no se han analizado las variables puede que no tengamos claro que queremos hacer si una codificación ordinal, una vectorización (onehot) o bien queremos hacer otro cambio en la variable y esos vienen dados por la relación de la categórica con el target y por tanto sólo se pueden ver en el train. Pero si por lo que sea sabemos seguros que vamos a hacer vectorización no hay problema en hacerlo antes del split. Por otro lado, siempre conviene quedarse con una categoria unkown para valores que pueden llegar en el futuro antes de un recalibrado.*

# %%
df["origin"] = df["origin"].map( {1.0: "USA", 2.0: "Europe", 3.0: "Japan"})

# %%
df = pd.get_dummies(df, columns = ["origin"], dtype = int)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0        4.0         140.0        86.0  2790.0          15.6
# 394  44.0        4.0          97.0        52.0  2130.0          24.6
# 395  32.0        4.0         135.0        84.0  2295.0          11.6
# 396  28.0        4.0         120.0        79.0  2625.0          18.6
# 397  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      model year  origin_Europe  origin_Japan  origin_USA
# 0          70.0              0             0           1
# 1          70.0              0             0           1
# 2          70.0              0             0           1
# 3          70.0              0             0           1
# 4          70.0              0             0           1
# ..          ...            ...           ...         ...
# 393        82.0              0             0           1
# 394        82.0              1             0           0
# 395        82.0              0             0           1
# 396        82.0              0             0           1
# 397        82.0              0             0           1
#
# [392 rows x 10 columns]

# %% [markdown]
# ### Ejercicio 4
#
# Divide los datos en train y test. Ahora divida el set de datos en un set de entrenamiento y otro de pruebas. 80% para entrenamiento
#
# Usaremos el set de pruebas en la evaluacion final de nuestro modelo. Emplea una variable target para guardar el nombre de la columna target.
#
# NOTA: El resultado tienen que ser dos datasets

# %%
train_set, test_set = train_test_split(df, train_size = 0.8, random_state = 42)

# %%
target = "mpg"

# %% [markdown]
# ### Ejercicio 5
#
# Inspecciona los datos. Revisa rápidamente la distribución conjunta del dataset de entrenamiento mediante un grid de gráficos

# %% [markdown]
# Visualizamos la distribución del *target*

# %%
sns.histplot(data = train_set, x = target, kde = True);

# %% [markdown]
# No es una distribución normal, pero tampoco es mala distribución

# %% [markdown]
# ** ME SALTO EL ANALISIS BIVARIANTE. EN LA SOLUCION ESTÁ **

# %%
features = [col for col in train_set.columns if col != target]
features
# Out:
# ['cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model year',
#  'origin_Europe',
#  'origin_Japan',
#  'origin_USA']

# %% [markdown]
# ### Ejercicio 6
#
# Independientemente de lo que hayas encontrado en el análisis anterior, vamos a utilizar todas las features y antes las vamos a escalar. Estandardiza train y test.

# %%
scaler = StandardScaler()

scaler.fit(train_set[features])

train_set[features] = scaler.transform(train_set[features])
test_set[features] = scaler.transform(test_set[features])

# %%
train_set[features].hist(figsize=(15,10));

# %% [markdown]
# ## El modelo

# %% [markdown]
# ### Ejercicio 7: Construye el modelo con Keras
#
# Construyamos nuestro modelo. Aquí, utilizaremos un modelo `secuencial` con dos capas ocultas densamente conectadas y una capa de salida que devuelve un único valor continuo. Es decir una MLP con dos capas ocultas.
#
# Por tanto, tendrá tres capas. Una inicial con activación relu (usa el argumento `input_shape` para darle el número de features). Otra hidden layer con activación relu y la de salida de regresión, que se compondrá de una única neurona. Pon las neuronas que consideres interesantes para las dos primeras capas (NOTA: En este caso partimos de pocas features, por lo que puede ser interesante poner 2 o 3 como mínimo el número de features para poder obtener unas pseudofeatures que intenten capturar las interrelaciones.)
#
# Otros datos:
#
# Para el compile utiliza un loss='mse'.
#
# optimizer = `tf.keras.optimizers.RMSprop(0.001)`
#
# Y en metrics añade en una lista el `mae` y `mse`.
#
# Utiliza una aproximación en prisma (mismo numero de unidades en las capas ocultas)

# %%
factor_expansion = 3
num_units = len(features) * factor_expansion

# %% [markdown]
# Método 1: como añadido de capas

# %%
model_add = keras.models.Sequential()

model_add.add(keras.layers.Dense(units = num_units, activation='relu', input_shape = [len(features)]))
model_add.add(keras.layers.Dense(units = num_units, activation='relu'))
model_add.add(keras.layers.Dense(units = 1))
# Out:
# WARNING:tensorflow:From c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# Método 2: usando las capas en los argumentos de la inicialización

# %%
model = keras.Sequential([
layers.Dense(num_units, activation='relu', input_shape=[len(features)]),
layers.Dense(num_units, activation='relu'),
layers.Dense(1)
])


model.compile(loss='mse',
              optimizer=tf.keras.optimizers.RMSprop(0.001),
              metrics=['mae', 'mse'])

# %% [markdown]
# ### Ejercicio 8
#
# Inspecciona el modelo usando el método `.summary` para imprimir una descripción simple del modelo

# %% [markdown]
# Inspeccionamos el modelo del método 1

# %%
model_add.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 27)                270
#
#  dense_1 (Dense)             (None, 27)                756
#
#  dense_2 (Dense)             (None, 1)                 28
#
# =================================================================
# Total params: 1054 (4.12 KB)
# Trainable params: 1054 (4.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Inspeccionamos el modelo del método 2

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 27)                270
#
#  dense_4 (Dense)             (None, 27)                756
#
#  dense_5 (Dense)             (None, 1)                 28
#
# =================================================================
# Total params: 1054 (4.12 KB)
# Trainable params: 1054 (4.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Tenemos 1054 parámetros que entrenar:
# * 1ª capa: 27 unidades * (9 + 1) features de entrada más el bias = 270 pesos
# * 2ª capa: 27 unidades * (27 + 1) salidas de la capa anterior más el bias = 756 pesos
# * Capa de salida: 1 unidad * (27 + 1) salidas de la capa anterior más el bias = 28 pesos

# %% [markdown]
# ### Ejercicio 9 Entrenar el modelo
#
# Entrena el modelo para 1000 epochs y guarda los resultados del entrenamiento en una variable llamada `history`.
# Emplea en el entrenamiento un 20% de los datos para validación, mediante el argumento `validation_split`.

# %%
X_train = train_set[features]
y_train = train_set[target]

X_test = test_set[features]
y_test = test_set[target]

# %%
history = model.fit(X_train, 
                    y_train,
                    epochs=1000, 
                    validation_split=0.2,
                    verbose=0)
# Out:
# WARNING:tensorflow:From c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\7681\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %% [markdown]
# ### Ejercicio 10
#
# Visualiza el progreso de entrenamiento del modelo usando las estadísticas almacenadas en el objeto `history`. Muestra la evolución del error en train y validation por un lado, y la evolución de la pérdida (loss), también train contra validation, en otra.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 995  4.204111  1.412099  4.204111  6.144752  1.818864  6.144752    995
# 996  4.209557  1.417606  4.209557  5.889118  1.788608  5.889118    996
# 997  4.260134  1.425018  4.260134  6.491804  1.870688  6.491804    997
# 998  4.279393  1.422709  4.279393  6.072272  1.809490  6.072272    998
# 999  4.179128  1.401761  4.179128  6.029817  1.804124  6.029817    999

# %%
def plot_history(history, error = True):
        
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  if error:
          
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [MPG]')
    
    plt.plot(hist['epoch'], hist['mae'],
            label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'],
            label = 'Val Error')
    
    plt.ylim([0,5])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [$MPG^2$]')
    
    plt.plot(hist['epoch'], hist['mse'],
            label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'],
            label = 'Val Error')
    
    plt.ylim([0,20])
    plt.legend()
    
    plt.show()

  else:
          
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    
    plt.plot(hist['epoch'], hist['loss'],
            label='Train loss')
    plt.plot(hist['epoch'], hist['val_loss'],
            label = 'Val loss')
    
    plt.legend()
    
    plt.show()

# %%
plot_history(history)

# %%
plot_history(history, error=False)

# %% [markdown]
# ### Ejercicio 11
#
# Comenta las gráficas anteriores.

# %% [markdown]
# Estos gráficos muestran poca mejora, o incluso degradación en el error de validación después de aproximadamente 100 épocas. Debemos actualizar la llamada `model.fit` para detener automáticamente el entrenamiento cuando el puntaje de validación no mejore

# %% [markdown]
# ### Ejercicio 12
#
# Independientemente de lo comentado en 11, vamos a añadir un callback al entrenamiento. Para ello, construye el modelo otra vez y vuelve a compilarlo (si no lo haces, como ya sabes comenzará el entrenamiento donde lo dejó y no nos valdrá el callback para nada). Entrena el modelo con los mismos hiperparámetros del ejercicio 10 y pinta la gráfica de evolución de los errores e interprétalo (obten el MAE medio una vez "estabilizado" el entrenamiento).
#
# Para el earlystopping utiliza un margen de 20 epochs.

# %%
model = keras.Sequential([
layers.Dense(num_units, activation='relu', input_shape=[len(features)]),
layers.Dense(num_units, activation='relu'),
layers.Dense(1)
])

model.compile(loss='mse',
            optimizer=tf.keras.optimizers.RMSprop(0.001),
            metrics=['mae', 'mse'])

history = model.fit(X_train,
                    y_train,
                    epochs=1000,
                    validation_split = 0.2,
                    verbose= 1,
                    callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 590.8954 - mae: 22.8747 - mse: 590.8954 - val_loss: 665.2081 - val_mae: 24.4866 - val_mse: 665.2081
# Epoch 2/1000
# 8/8 [==============================] - 0s 5ms/step - loss:
1000
# 8/8 [==============================] - 0s 6ms/step - loss: 88.1448 - mae: 7.7256 - mse: 88.1448 - val_loss: 105.2782 - val_mae: 8.2833 - val_mse: 105.2782
# Epoch 25/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 73.6162 - mae: 6.9766 - mse: 73.6162 - val_loss: 88.7192 - val_mae: 7.4367 - val_mse: 88.7192
# Epoch 26/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 61.2629 - mae: 6.2953 - mse: 61.2629 - val_loss: 75.0492 - val_mae: 6.6545 - val_mse: 75.0492
# Epoch 27/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 51.2313 - mae: 5.7210 - mse: 51.2313 - val_loss: 63.2985 - val_mae: 5.9880 - val_mse: 63.2985
# Epoch 28/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 43.4448 - mae: 5.2995 - mse: 43.4448 - val_loss: 54.4079 - val_mae: 5.5160 - val_mse: 54.4079
# Epoch 29/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 37.3950 - mae: 4.9282 - mse: 37.3950 - val_loss: 46.4902 - val_mae: 5.1430 - val_mse: 46.4902
# Epoch 30/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 32.5638 - mae: 4.6322 - mse: 32.5638 - val_loss: 40.5300 - val_mae: 4.7974 - val_mse: 40.5300
# Epoch 31/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 28.3649 - mae: 4.3233 - mse: 28.3649 - val_loss: 34.7467 - val_mae: 4.4306 - val_mse: 34.7467
# Epoch 32/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 24.8433 - mae: 4.0396 - mse: 24.8433 - val_loss: 30.0325 - val_mae: 4.0959 - val_mse: 30.0325
# Epoch 33/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 21.8222 - mae: 3.7879 - mse: 21.8222 - val_loss: 26.1923 - val_mae: 3.7881 - val_mse: 26.1923
# Epoch 34/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 19.3591 - mae: 3.5302 - mse: 19.3591 - val_loss: 23.0312 - val_mae: 3.5244 - val_mse: 23.0312
# Epoch 35/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 17.3362 - mae: 3.3005 - mse: 17.3362 - val_loss: 20.3502 - val_mae: 3.2712 - val_mse: 20.3502
# Epoch 36/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 15.8302 - mae: 3.1466 - mse: 15.8302 - val_loss: 18.2539 - val_mae: 3.0576 - val_mse: 18.2539
# Epoch 37/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 14.7365 - mae: 3.0213 - mse: 14.7365 - val_loss: 16.7913 - val_mae: 2.9257 - val_mse: 16.7913
# Epoch 38/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 13.7768 - mae: 2.9191 - mse: 13.7768 - val_loss: 15.5473 - val_mae: 2.7990 - val_mse: 15.5473
# Epoch 39/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 13.0115 - mae: 2.8237 - mse: 13.0115 - val_loss: 14.4771 - val_mae: 2.6956 - val_mse: 14.4771
# Epoch 40/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 12.3804 - mae: 2.7378 - mse: 12.3804 - val_loss: 13.2954 - val_mae: 2.5574 - val_mse: 13.2954
# Epoch 41/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 11.9074 - mae: 2.6666 - mse: 11.9074 - val_loss: 12.5622 - val_mae: 2.4678 - val_mse: 12.5622
# Epoch 42/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 11.5167 - mae: 2.6288 - mse: 11.5167 - val_loss: 11.8302 - val_mae: 2.3858 - val_mse: 11.8302
# Epoch 43/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 11.0872 - mae: 2.5714 - mse: 11.0872 - val_loss: 11.2451 - val_mae: 2.3306 - val_mse: 11.2451
# Epoch 44/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.7412 - mae: 2.4945 - mse: 10.7412 - val_loss: 10.8460 - val_mae: 2.2902 - val_mse: 10.8460
# Epoch 45/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.4307 - mae: 2.4712 - mse: 10.4307 - val_loss: 10.6769 - val_mae: 2.2668 - val_mse: 10.6769
# Epoch 46/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.3298 - mae: 2.4313 - mse: 10.3298 - val_loss: 9.9754 - val_mae: 2.1925 - val_mse: 9.9754
# Epoch 47/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.0943 - mae: 2.3967 - mse: 10.0943 - val_loss: 9.7393 - val_mae: 2.1675 - val_mse: 9.7393
# Epoch 48/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.7714 - mae: 2.3467 - mse: 9.7714 - val_loss: 9.3236 - val_mae: 2.1178 - val_mse: 9.3236
# Epoch 49/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.4945 - mae: 2.3121 - mse: 9.4945 - val_loss: 9.4499 - val_mae: 2.1259 - val_mse: 9.4499
# Epoch 50/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 9.5818 - mae: 2.3133 - mse: 9.5818 - val_loss: 8.8938 - val_mae: 2.0685 - val_mse: 8.8938
# Epoch 51/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.3426 - mae: 2.2641 - mse: 9.3426 - val_loss: 8.6249 - val_mae: 2.0359 - val_mse: 8.6249
# Epoch 52/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 9.1838 - mae: 2.2364 - mse: 9.1838 - val_loss: 8.6182 - val_mae: 2.0300 - val_mse: 8.6182
# Epoch 53/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.1294 - mae: 2.2223 - mse: 9.1294 - val_loss: 8.7952 - val_mae: 2.0378 - val_mse: 8.7952
# Epoch 54/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8.9825 - mae: 2.1966 - mse: 8.9825 - val_loss: 8.3161 - val_mae: 1.9900 - val_mse: 8.3161
# Epoch 55/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8.8120 - mae: 2.1800 - mse: 8.8120 - val_loss: 8.1512 - val_mae: 1.9673 - val_mse: 8.1512
# Epoch 56/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 8.8239 - mae: 2.1677 - mse: 8.8239 - val_loss: 7.9553 - val_mae: 1.9467 - val_mse: 7.9553
# Epoch 57/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8.6402 - mae: 2.1643 - mse: 8.6402 - val_loss: 7.8635 - val_mae: 1.9390 - val_mse: 7.8635
# Epoch 58/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 8.7013 - mae: 2.1366 - mse: 8.7013 - val_loss: 7.7450 - val_mae: 1.9283 - val_mse: 7.7450
# Epoch 59/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 8.4102 - mae: 2.1258 - mse: 8.4102 - val_loss: 7.9937 - val_mae: 1.9519 - val_mse: 7.9937
# Epoch 60/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8.3860 - mae: 2.1140 - mse: 8.3860 - val_loss: 8.1767 - val_mae: 1.9940 - val_mse: 8.1767
# Epoch 61/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 8.4575 - mae: 2.1125 - mse: 8.4575 - val_loss: 7.5603 - val_mae: 1.8906 - val_mse: 7.5603
# Epoch 62/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 8.3328 - mae: 2.1141 - mse: 8.3328 - val_loss: 7.7295 - val_mae: 1.9159 - val_mse: 7.7295
# Epoch 63/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8.3431 - mae: 2.0966 - mse: 8.3431 - val_loss: 7.3327 - val_mae: 1.8812 - val_mse: 7.3327
# Epoch 64/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8.1509 - mae: 2.0785 - mse: 8.1509 - val_loss: 7.5145 - val_mae: 1.8898 - val_mse: 7.5145
# Epoch 65/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 8.0348 - mae: 2.0503 - mse: 8.0348 - val_loss: 7.2617 - val_mae: 1.8715 - val_mse: 7.2617
# Epoch 66/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 8.1291 - mae: 2.0745 - mse: 8.1291 - val_loss: 7.3084 - val_mae: 1.8647 - val_mse: 7.3084
# Epoch 67/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 7.9550 - mae: 2.0394 - mse: 7.9550 - val_loss: 7.1819 - val_mae: 1.8560 - val_mse: 7.1819
# Epoch 68/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8
1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.0954 - mae: 1.9171 - mse: 7.0954 - val_loss: 6.7048 - val_mae: 1.8796 - val_mse: 6.7048
# Epoch 113/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 7.0312 - mae: 1.8841 - mse: 7.0312 - val_loss: 6.5666 - val_mae: 1.8502 - val_mse: 6.5666
# Epoch 114/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 7.1141 - mae: 1.8979 - mse: 7.1141 - val_loss: 6.8983 - val_mae: 1.9111 - val_mse: 6.8983
# Epoch 115/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 7.0994 - mae: 1.9050 - mse: 7.0994 - val_loss: 6.6913 - val_mae: 1.8756 - val_mse: 6.6913
# Epoch 116/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.9832 - mae: 1.8756 - mse: 6.9832 - val_loss: 6.6947 - val_mae: 1.8828 - val_mse: 6.6947
# Epoch 117/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 7.0231 - mae: 1.8890 - mse: 7.0231 - val_loss: 6.5923 - val_mae: 1.8621 - val_mse: 6.5923
# Epoch 118/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 7.1417 - mae: 1.8992 - mse: 7.1417 - val_loss: 6.6463 - val_mae: 1.8719 - val_mse: 6.6463
# Epoch 119/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.9959 - mae: 1.8962 - mse: 6.9959 - val_loss: 7.1333 - val_mae: 1.9531 - val_mse: 7.1333
# Epoch 120/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.9755 - mae: 1.8815 - mse: 6.9755 - val_loss: 6.6596 - val_mae: 1.8811 - val_mse: 6.6596
# Epoch 121/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 7.0090 - mae: 1.8978 - mse: 7.0090 - val_loss: 6.4410 - val_mae: 1.8348 - val_mse: 6.4410
# Epoch 122/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8801 - mae: 1.8859 - mse: 6.8801 - val_loss: 6.7007 - val_mae: 1.8886 - val_mse: 6.7007
# Epoch 123/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.9265 - mae: 1.8656 - mse: 6.9265 - val_loss: 6.3389 - val_mae: 1.8074 - val_mse: 6.3389
# Epoch 124/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.9598 - mae: 1.8729 - mse: 6.9598 - val_loss: 6.4478 - val_mae: 1.8497 - val_mse: 6.4478
# Epoch 125/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.8441 - mae: 1.8787 - mse: 6.8441 - val_loss: 7.1788 - val_mae: 1.9707 - val_mse: 7.1788
# Epoch 126/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.9506 - mae: 1.8719 - mse: 6.9506 - val_loss: 6.5856 - val_mae: 1.8750 - val_mse: 6.5856
# Epoch 127/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.9597 - mae: 1.8697 - mse: 6.9597 - val_loss: 6.4103 - val_mae: 1.8392 - val_mse: 6.4103
# Epoch 128/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.9392 - mae: 1.8861 - mse: 6.9392 - val_loss: 6.5336 - val_mae: 1.8628 - val_mse: 6.5336
# Epoch 129/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8830 - mae: 1.8587 - mse: 6.8830 - val_loss: 6.3422 - val_mae: 1.8221 - val_mse: 6.3422
# Epoch 130/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8557 - mae: 1.8728 - mse: 6.8557 - val_loss: 7.0248 - val_mae: 1.9454 - val_mse: 7.0248
# Epoch 131/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.9022 - mae: 1.8600 - mse: 6.9022 - val_loss: 6.4675 - val_mae: 1.8480 - val_mse: 6.4675
# Epoch 132/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.9052 - mae: 1.8784 - mse: 6.9052 - val_loss: 7.1157 - val_mae: 1.9607 - val_mse: 7.1157
# Epoch 133/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.8593 - mae: 1.8593 - mse: 6.8593 - val_loss: 6.7598 - val_mae: 1.9076 - val_mse: 6.7598
# Epoch 134/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.8201 - mae: 1.8581 - mse: 6.8201 - val_loss: 6.5122 - val_mae: 1.8644 - val_mse: 6.5122
# Epoch 135/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.8232 - mae: 1.8717 - mse: 6.8232 - val_loss: 6.7312 - val_mae: 1.9054 - val_mse: 6.7312
# Epoch 136/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8568 - mae: 1.8507 - mse: 6.8568 - val_loss: 6.6287 - val_mae: 1.8886 - val_mse: 6.6287
# Epoch 137/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8213 - mae: 1.8526 - mse: 6.8213 - val_loss: 6.4483 - val_mae: 1.8574 - val_mse: 6.4483
# Epoch 138/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8963 - mae: 1.8628 - mse: 6.8963 - val_loss: 6.6022 - val_mae: 1.8879 - val_mse: 6.6022
# Epoch 139/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8247 - mae: 1.8505 - mse: 6.8247 - val_loss: 6.7584 - val_mae: 1.9145 - val_mse: 6.7584
# Epoch 140/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.7235 - mae: 1.8260 - mse: 6.7235 - val_loss: 6.3228 - val_mae: 1.8262 - val_mse: 6.3228
# Epoch 141/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 6.8626 - mae: 1.8727 - mse: 6.8626 - val_loss: 6.3456 - val_mae: 1.8386 - val_mse: 6.3456
# Epoch 142/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.7691 - mae: 1.8623 - mse: 6.7691 - val_loss: 6.7167 - val_mae: 1.9068 - val_mse: 6.7167
# Epoch 143/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.7324 - mae: 1.8424 - mse: 6.7324 - val_loss: 6.4331 - val_mae: 1.8609 - val_mse: 6.4331
# Epoch 144/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.7039 - mae: 1.8408 - mse: 6.7039 - val_loss: 6.3098 - val_mae: 1.8373 - val_mse: 6.3098
# Epoch 145/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6896 - mae: 1.8333 - mse: 6.6896 - val_loss: 6.5224 - val_mae: 1.8773 - val_mse: 6.5224
# Epoch 146/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.8090 - mae: 1.8517 - mse: 6.8090 - val_loss: 6.5587 - val_mae: 1.8853 - val_mse: 6.5587
# Epoch 147/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.7439 - mae: 1.8258 - mse: 6.7439 - val_loss: 6.5760 - val_mae: 1.8887 - val_mse: 6.5760
# Epoch 148/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.7956 - mae: 1.8321 - mse: 6.7956 - val_loss: 6.3232 - val_mae: 1.8433 - val_mse: 6.3232
# Epoch 149/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.7875 - mae: 1.8581 - mse: 6.7875 - val_loss: 6.4338 - val_mae: 1.8664 - val_mse: 6.4338
# Epoch 150/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.6834 - mae: 1.8360 - mse: 6.6834 - val_loss: 6.4418 - val_mae: 1.8620 - val_mse: 6.4418
# Epoch 151/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6262 - mae: 1.8240 - mse: 6.6262 - val_loss: 6.2071 - val_mae: 1.7937 - val_mse: 6.2071
# Epoch 152/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6778 - mae: 1.8305 - mse: 6.6778 - val_loss: 6.7450 - val_mae: 1.9158 - val_mse: 6.7450
# Epoch 153/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.6544 - mae: 1.8397 - mse: 6.6544 - val_loss: 6.2973 - val_mae: 1.8485 - val_mse: 6.2973
# Epoch 154/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6486 - mae: 1.8340 - mse: 6.6486 - val_loss: 6.2815 - val_mae: 1.8435 - val_mse: 6.2815
# Epoch 155/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 6.8113 - mae: 1.8381 - mse: 6.8113 - val_loss: 6.2603 - val_mae: 1.8398 - val_mse: 6.2603
# Epoch 156/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.6566 - mae: 1.8328 - mse: 6.6566 - val_loss: 6.2786 - val_mae: 1.8430 - val_mse: 6.2786
# Epoch 157/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.6102 - mae: 1.8192 - mse: 6.6102 - val_loss: 6.8504 - val_mae: 1.9357 - val_mse: 6.8504
# Epoch 158/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6932 - mae: 1.8450 - mse: 6.6932 - val_loss: 6.6240 - val_mae: 1.9021 - val_mse: 6.6240
# Epoch 159/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.6374 - mae: 1.8233 - mse: 6.6374 - val_loss: 6.4280 - val_mae: 1.8682 - val_mse: 6.4280
# Epoch 160/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6206 - mae: 1.8266 - mse: 6.6206 - val_loss: 6.5747 - val_mae: 1.8944 - val_mse: 6.5747
# Epoch 161/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6102 - mae: 1.8220 - mse: 6.6102 - val_loss: 6.5098 - val_mae: 1.8874 - val_mse: 6.5098
# Epoch 162/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.6838 - mae: 1.8269 - mse: 6.6838 - val_loss: 6.2003 - val_mae: 1.8332 - val_mse: 6.2003
# Epoch 163/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.5932 - mae: 1.8181 - mse: 6.5932 - val_loss: 6.5648 - val_mae: 1.8950 - val_mse: 6.5648
# Epoch 164/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.7246 - mae: 1.8286 - mse: 6.7246 - val_loss: 6.3015 - val_mae: 1.8487 - val_mse: 6.3015
# Epoch 165/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6477 - mae: 1.8334 - mse: 6.6477 - val_loss: 6.7112 - val_mae: 1.9157 - val_mse: 6.7112
# Epoch 166/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.6225 - mae: 1.8152 - mse: 6.6225 - val_loss: 6.2064 - val_mae: 1.8297 - val_mse: 6.2064
# Epoch 167/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5898 - mae: 1.8336 - mse: 6.5898 - val_loss: 6.3887 - val_mae: 1.8640 - val_mse: 6.3887
# Epoch 168/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6076 - mae: 1.8098 - mse: 6.6076 - val_loss: 6.2384 - val_mae: 1.8405 - val_mse: 6.2384
# Epoch 169/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5420 - mae: 1.8066 - mse: 6.5420 - val_loss: 6.1043 - val_mae: 1.8091 - val_mse: 6.1043
# Epoch 170/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6027 - mae: 1.8195 - mse: 6.6027 - val_loss: 6.4210 - val_mae: 1.8774 - val_mse: 6.4210
# Epoch 171/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6147 - mae: 1.8229 - mse: 6.6147 - val_loss: 6.3652 - val_mae: 1.8682 - val_mse: 6.3652
# Epoch 172/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.6116 - mae: 1.8182 - mse: 6.6116 - val_loss: 6.4910 - val_mae: 1.8867 - val_mse: 6.4910
# Epoch 173/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5358 - mae: 1.8036 - mse: 6.5358 - val_loss: 6.3351 - val_mae: 1.8657 - val_mse: 6.3351
# Epoch 174/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4917 - mae: 1.7975 - mse: 6.4917 - val_loss: 6.1114 - val_mae: 1.8154 - val_mse: 6.1114
# Epoch 175/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5977 - mae: 1.8273 - mse: 6.5977 - val_loss: 6.2092 - val_mae: 1.8472 - val_mse: 6.2092
# Epoch 176/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6314 - mae: 1.8214 - mse: 6.6314 - val_loss: 6.5046 - val_mae: 1.8930 - val_mse: 6.5046
# Epoch 177/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5427 - mae: 1.8080 - mse: 6.5427 - val_loss: 6.3526 - val_mae: 1.8673 - val_mse: 6.3526
# Epoch 178/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.5157 - mae: 1.8109 - mse: 6.5157 - val_loss: 6.2095 - val_mae: 1.8432 - val_mse: 6.2095
# Epoch 179/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.5872 - mae: 1.8302 - mse: 6.5872 - val_loss: 6.9239 - val_mae: 1.9519 - val_mse: 6.9239
# Epoch 180/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.5425 - mae: 1.8067 - mse: 6.5425 - val_loss: 6.1316 - val_mae: 1.8225 - val_mse: 6.1316
# Epoch 181/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5055 - mae: 1.7967 - mse: 6.5055 - val_loss: 6.0912 - val_mae: 1.8150 - val_mse: 6.0912
# Epoch 182/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5565 - mae: 1.8089 - mse: 6.5565 - val_loss: 6.0671 - val_mae: 1.8161 - val_mse: 6.0671
# Epoch 183/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4974 - mae: 1.8092 - mse: 6.4974 - val_loss: 6.3231 - val_mae: 1.8694 - val_mse: 6.3231
# Epoch 184/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.4637 - mae: 1.7943 - mse: 6.4637 - val_loss: 6.5068 - val_mae: 1.8974 - val_mse: 6.5068
# Epoch 185/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4164 - mae: 1.7786 - mse: 6.4164 - val_loss: 6.0444 - val_mae: 1.8200 - val_mse: 6.0444
# Epoch 186/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.4824 - mae: 1.7862 - mse: 6.4824 - val_loss: 6.1841 - val_mae: 1.8448 - val_mse: 6.1841
# Epoch 187/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.5886 - mae: 1.8083 - mse: 6.5886 - val_loss: 6.0891 - val_mae: 1.8254 - val_mse: 6.0891
# Epoch 188/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4949 - mae: 1.8032 - mse: 6.4949 - val_loss: 6.0681 - val_mae: 1.8221 - val_mse: 6.0681
# Epoch 189/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5391 - mae: 1.8170 - mse: 6.5391 - val_loss: 6.3433 - val_mae: 1.8766 - val_mse: 6.3433
# Epoch 190/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5170 - mae: 1.8227 - mse: 6.5170 - val_loss: 6.2806 - val_mae: 1.8639 - val_mse: 6.2806
# Epoch 191/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.4743 - mae: 1.7831 - mse: 6.4743 - val_loss: 6.1776 - val_mae: 1.8505 - val_mse: 6.1776
# Epoch 192/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.4412 - mae: 1.7963 - mse: 6.4412 - val_loss: 6.1379 - val_mae: 1.8454 - val_mse: 6.1379
# Epoch 193/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4399 - mae: 1.7869 - mse: 6.4399 - val_loss: 6.2047 - val_mae: 1.8457 - val_mse: 6.2047
# Epoch 194/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.3885 - mae: 1.7794 - mse: 6.3885 - val_loss: 6.0109 - val_mae: 1.8082 - val_mse: 6.0109
# Epoch 195/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.4060 - mae: 1.8318 - mse: 6.4060 - val_loss: 6.5011 - val_mae: 1.9012 - val_mse: 6.5011
# Epoch 196/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4467 - mae: 1.7937 - mse: 6.4467 - val_loss: 6.4675 - val_mae: 1.8961 - val_mse: 6.4675
# Epoch 197/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5005 - mae: 1.8038 - mse: 6.5005 - val_loss: 6.1456 - val_mae: 1.8386 - val_mse: 6.1456
# Epoch 198/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.4807 - mae: 1.7974 - mse: 6.4807 - val_loss: 6.2804 - val_mae: 1.8682 - val_mse: 6.2804
# Epoch 199/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 6.4026 - mae: 1.7958 - mse: 6.4026 - val_loss: 6.3330 - val_mae: 1.8749 - val_mse: 6.3330
# Epoch 200/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.4090 - mae: 1.7837 - mse: 6.4090 - val_loss: 6.3892 - val_mae: 1.8826 - val_mse: 6.3892
# Epoch 201/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4682 - mae: 1.8015 - mse: 6.4682 - val_loss: 6.1828 - val_mae: 1.8534 - val_mse: 6.1828
# Epoch 202/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.4560 - mae: 1.7815 - mse: 6.4560 - val_loss: 6.2068 - val_mae: 1.8587 - val_mse: 6.2068
# Epoch 203/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.3769 - mae: 1.7844 - mse: 6.3769 - val_loss: 6.2558 - val_mae: 1.8634 - val_mse: 6.2558
# Epoch 204/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.4016 - mae: 1.7748 - mse: 6.4016 - val_loss: 6.1724 - val_mae: 1.8487 - val_mse: 6.1724
# Epoch 205/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5633 - mae: 1.8104 - mse: 6.5633 - val_loss: 6.2335 - val_mae: 1.8619 - val_mse: 6.2335
# Epoch 206/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.4111 - mae: 1.7953 - mse: 6.4111 - val_loss: 6.2034 - val_mae: 1.8549 - val_mse: 6.2034
# Epoch 207/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5515 - mae: 1.7951 - mse: 6.5515 - val_loss: 6.0405 - val_mae: 1.8252 - val_mse: 6.0405
# Epoch 208/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.3558 - mae: 1.7800 - mse: 6.3558 - val_loss: 6.3400 - val_mae: 1.8775 - val_mse: 6.3400
# Epoch 209/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.2995 - mae: 1.7500 - mse: 6.2995 - val_loss: 6.0937 - val_mae: 1.8376 - val_mse: 6.0937
# Epoch 210/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2879 - mae: 1.7804 - mse: 6.2879 - val_loss: 6.6291 - val_mae: 1.9143 - val_mse: 6.6291
# Epoch 211/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.3618 - mae: 1.7633 - mse: 6.3618 - val_loss: 6.0015 - val_mae: 1.8172 - val_mse: 6.0015
# Epoch 212/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.3853 - mae: 1.7696 - mse: 6.3853 - val_loss: 6.0851 - val_mae: 1.8399 - val_mse: 6.0851
# Epoch 213/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2538 - mae: 1.7615 - mse: 6.2538 - val_loss: 5.8218 - val_mae: 1.7818 - val_mse: 5.8218
# Epoch 214/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.3932 - mae: 1.7939 - mse: 6.3932 - val_loss: 6.2599 - val_mae: 1.8700 - val_mse: 6.2599
# Epoch 215/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 6.3276 - mae: 1.7619 - mse: 6.3276 - val_loss: 5.8520 - val_mae: 1.7915 - val_mse: 5.8520
# Epoch 216/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2697 - mae: 1.7699 - mse: 6.2697 - val_loss: 6.2386 - val_mae: 1.8640 - val_mse: 6.2386
# Epoch 217/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.2306 - mae: 1.7856 - mse: 6.2306 - val_loss: 6.8000 - val_mae: 1.9372 - val_mse: 6.8000
# Epoch 218/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.4681 - mae: 1.7809 - mse: 6.4681 - val_loss: 6.4074 - val_mae: 1.8877 - val_mse: 6.4074
# Epoch 219/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2526 - mae: 1.7748 - mse: 6.2526 - val_loss: 5.9455 - val_mae: 1.8091 - val_mse: 5.9455
# Epoch 220/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.3344 - mae: 1.7846 - mse: 6.3344 - val_loss: 6.1965 - val_mae: 1.8572 - val_mse: 6.1965
# Epoch 221/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.3722 - mae: 1.7848 - mse: 6.3722 - val_loss: 6.2915 - val_mae: 1.8740 - val_mse: 6.2915
# Epoch 222/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.3457 - mae: 1.7701 - mse: 6.3457 - val_loss: 6.4895 - val_mae: 1.8979 - val_mse: 6.4895
# Epoch 223/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2632 - mae: 1.7509 - mse: 6.2632 - val_loss: 5.9541 - val_mae: 1.8133 - val_mse: 5.9541
# Epoch 224/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.1759 - mae: 1.7576 - mse: 6.1759 - val_loss: 6.8413 - val_mae: 1.9400 - val_mse: 6.8413
# Epoch 225/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.2513 - mae: 1.7611 - mse: 6.2513 - val_loss: 6.0585 - val_mae: 1.8335 - val_mse: 6.0585
# Epoch 226/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.3110 - mae: 1.7575 - mse: 6.3110 - val_loss: 6.0231 - val_mae: 1.8270 - val_mse: 6.0231
# Epoch 227/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2609 - mae: 1.7615 - mse: 6.2609 - val_loss: 5.9771 - val_mae: 1.8212 - val_mse: 5.9771
# Epoch 228/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2406 - mae: 1.7527 - mse: 6.2406 - val_loss: 5.9154 - val_mae: 1.8063 - val_mse: 5.9154
# Epoch 229/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.3920 - mae: 1.7662 - mse: 6.3920 - val_loss: 6.1409 - val_mae: 1.8504 - val_mse: 6.1409
# Epoch 230/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.2247 - mae: 1.7551 - mse: 6.2247 - val_loss: 5.9324 - val_mae: 1.8173 - val_mse: 5.9324
# Epoch 231/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2515 - mae: 1.7700 - mse: 6.2515 - val_loss: 6.0743 - val_mae: 1.8412 - val_mse: 6.0743
# Epoch 232/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.2792 - mae: 1.7602 - mse: 6.2792 - val_loss: 6.2759 - val_mae: 1.8703 - val_mse: 6.2759
# Epoch 233/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.2981 - mae: 1.7535 - mse: 6.2981 - val_loss: 6.0268 - val_mae: 1.8280 - val_mse: 6.0268

# %%
plot_history(history)

# %% [markdown]
# Interpreta el gráfico

# %% [markdown]
# Se ve que no eran necesarias tantas épocas ya que antes de las 200 ha terminado. Además, sobre las 80 epocas se estabiliza

# %%
hist = pd.DataFrame(history.history)
hist
# Out:
#            loss        mae         mse    val_loss    val_mae     val_mse
# 0    590.895386  22.874699  590.895386  665.208069  24.486643  665.208069
# 1    573.845703  22.479479  573.845703  649.894897  24.155939  649.894897
# 2    559.276855  22.139309  559.276855  634.576721  23.824013  634.576721
# 3    544.638123  21.787041  544.638123  618.968262  23.476923  618.968262
# 4    529.161560  21.411537  529.161560  601.917114  23.092281  601.917114
# ..          ...        ...         ...         ...        ...         ...
# 228    6.392001   1.766187    6.392001    6.140908   1.850420    6.140908
# 229    6.224710   1.755143    6.224710    5.932447   1.817291    5.932447
# 230    6.251459   1.770028    6.251459    6.074258   1.841241    6.074258
# 231    6.279221   1.760159    6.279221    6.275902   1.870347    6.275902
# 232    6.298128   1.753533    6.298128    6.026800   1.828000    6.026800
#
# [233 rows x 6 columns]

# %% [markdown]
# Observamos el valor de MAE con mayor frecuencia y la media, a partir de la época 80

# %%
hist[80:].val_mae.hist();

# %%
mae = hist[80:].val_mae.mean()
mae
# Out:
# 1.866034716562508

# %% [markdown]
# El gráfico muestra que en el conjunto de validación, el error promedio generalmente es de alrededor de +/- 2 MPG

# %% [markdown]
# ### Ejercicio 13

# %% [markdown]
# Veamos qué tan bien generaliza el modelo al usar el conjunto de **test**. Esto nos dice qué tan bien podemos esperar que el modelo prediga cuándo lo usamos en el mundo real. Utiliza el método `evaluate` con los datos de test normalizados y sus labels.
#
# Con el método evaluate devolverá tres valores: loss, mae y mse.

# %%
loss, mae, mse = model.evaluate(X_test, y_test, verbose=1)

print("Testing set Mean Abs Error: {:.2f} MPG".format(mae))
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 5.9551 - mae: 1.7892 - mse: 5.9551
# Testing set Mean Abs Error: 1.79 MPG

# %% [markdown]
# Calculamos el MAPE

# %%
mape = (mae/y_test.mean())*100
print("MAPE: {:.2f}%".format(mape))
# Out:
# MAPE: 7.83%

# %% [markdown]
# ### Ejercicio 14
#
# Dibuja en un scatter plot las predicciones de test vs sus true labels.

# %%
y_pred = model.predict(X_test).flatten() # Hay que aplanar porque devuelve un array de dos dimensiones

plt.scatter(y_test, y_pred)

plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')

plt.axis('equal')
plt.axis('square')

plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])

plt.plot([-100, 100], [-100, 100]);
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %% [markdown]
# Visualizamos la distribución de errores

# %%
error = y_test - y_pred

plt.hist(error, bins = 25)

plt.xlabel("Prediction Error [MPG]")
plt.ylabel("Count");
